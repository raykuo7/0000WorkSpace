# %% [markdown]
# 我想用python做一個程式:
# 1. 批量讀入照片
# 2. 依序顯示每張照片，並可以手動選取圖片上的點
# 3. 記錄點座標並寫成 .csv檔
# 4. .csv檔格式為 image_path, x, y

# %%
import cv2
import pandas as pd
import glob

# Initialize an empty list to store the data
data = []

# Define initial display scale factor
scale_factor = 1.0
min_scale = 0.1
max_scale = 3.0

# Callback function to record points
def select_point(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        # Calculate original coordinates based on current scale factor
        orig_x = int(x / scale_factor)
        orig_y = int(y / scale_factor)
        data.append((param, orig_x, orig_y))
        print(f"Point selected at: x={orig_x}, y={orig_y}")

# Load images from a directory (replace 'your_image_folder_path' with your folder path)
image_files = glob.glob('..\..\fantest_pic\pic_train_1127\*.png')  # Adjust file extension as needed

# Process each image
for img_path in image_files:
    # Read the original image
    img = cv2.imread(img_path)
    h, w = img.shape[:2]
    
    # Display the image with interactive scaling
    while True:
        # Resize image according to the current scale factor
        display_img = cv2.resize(img, (int(w * scale_factor), int(h * scale_factor)))
        
        # Show the image and set the callback
        cv2.imshow("Image", display_img)
        cv2.setMouseCallback("Image", select_point, img_path)
        
        print("Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image.")
        key = cv2.waitKey(0)
        
        if key == ord('n'):
            break
        elif key == ord('+') and scale_factor < max_scale:
            scale_factor += 0.1
        elif key == ord('-') and scale_factor > min_scale:
            scale_factor -= 0.1
        elif key == ord('q'):  # Optional: press 'q' to quit early
            break
    
    if key == ord('q'):
        break

cv2.destroyAllWindows()

# Save the data to a CSV file
df = pd.DataFrame(data, columns=["image_path", "x", "y"])
df.to_csv("selected_points.csv", index=False)
print("Data saved to selected_points.csv")
# Out:
# Data saved to selected_points.csv

# %%
import cv2
import pandas as pd
import glob
import sys

# Initialize an empty list to store the data
data = []

# Define initial display scale factor
scale_factor = 1.0
min_scale = 0.1
max_scale = 3.0

# Global quit flag
quit_flag = False

# Callback function to record points
def select_point(event, x, y, flags, param):
    if event == cv2.EVENT_LBUTTONDOWN:
        # Calculate original coordinates based on current scale factor
        orig_x = int(x / scale_factor)
        orig_y = int(y / scale_factor)
        data.append((param, orig_x, orig_y))
        print(f"Point selected at: x={orig_x}, y={orig_y}")

# Load images from a directory (adjust the path)
# image_files = glob.glob(r'..\..\fantest_pic\pic_train\*.png')  # Adjust file extension as needed

image_files = glob.glob(r'D:\GitHub\0000WorkSpace\test1127\pic_train_100less\*.png')

if not image_files:
    print("No images found. Please check the path and try again.")
    sys.exit()

# Process each image
for img_path in image_files:
    if quit_flag:  # If quit_flag is True, exit the loop
        break
    
    # Read the original image
    img = cv2.imread(img_path)
    if img is None:
        print(f"Failed to load image: {img_path}")
        continue
    h, w = img.shape[:2]
    
    # Display the image with interactive scaling
    while True:
        if quit_flag:  # If quit_flag is True, exit the loop
            break
        
        # Resize image according to the current scale factor
        display_img = cv2.resize(img, (int(w * scale_factor), int(h * scale_factor)))
        
        # Show the image and set the callback
        window_name = f"Image: {img_path}"
        cv2.imshow(window_name, display_img)
        cv2.setMouseCallback(window_name, select_point, img_path)
        
        print("Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.")
        key = cv2.waitKey(0) & 0xFF  # Handle multi-byte input
        
        if key == ord('n'):  # Move to the next image
            break
        elif key == ord('+') and scale_factor < max_scale:  # Zoom in
            scale_factor += 0.1
            print(f"Zoom in: Current scale factor = {scale_factor:.1f}")
        elif key == ord('-') and scale_factor > min_scale:  # Zoom out
            scale_factor -= 0.1
            print(f"Zoom out: Current scale factor = {scale_factor:.1f}")
        elif key == ord('q'):  # Quit the program
            quit_flag = True
            break
    
    cv2.destroyWindow(window_name)  # Close current image window

# Cleanup and save data if not quitting early
if not quit_flag:
    cv2.destroyAllWindows()

# Save the data to a CSV file
if data:
    df = pd.DataFrame(data, columns=["image_path", "x", "y"])
    df.to_csv("selected_points.csv", index=False)
    print("Data saved to selected_points.csv")
else:
    print("No points selected.")
# Out:
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom out: Current scale factor = 0.9
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom out: Current scale factor = 0.8
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom out: Current scale factor = 0.7
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom out: Current scale factor = 0.6
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom in: Current scale factor = 0.7
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom in: Current scale factor = 0.8
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1498, y=495
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1508, y=535
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1563, y=925
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1567, y=966
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1570, y=1010
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1577, y=1131
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1580, y=1168
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1580, y=1210
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1517, y=580
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom out: Current scale factor = 0.7
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1578, y=1328
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1577, y=1368
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1574, y=1408
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom out: Current scale factor = 0.6
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1564, y=1518
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1561, y=1554
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1561, y=1589
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom out: Current scale factor = 0.5
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1543, y=1689
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1537, y=1725
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1529, y=1763
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1511, y=1855
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1501, y=1887
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom out: Current scale factor = 0.4
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1494, y=1917
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1469, y=2007
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1454, y=2032
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1442, y=2059
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1404, y=2134
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1397, y=2162
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1379, y=2187
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom in: Current scale factor = 0.5
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom in: Current scale factor = 0.6
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom in: Current scale factor = 0.7
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom in: Current scale factor = 0.8
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom in: Current scale factor = 0.9
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1538, y=711
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom out: Current scale factor = 0.8
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom out: Current scale factor = 0.7
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom out: Current scale factor = 0.6
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom out: Current scale factor = 0.5
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom out: Current scale factor = 0.4
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1342, y=2257
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1327, y=2277
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1312, y=2297
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1259, y=2354
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1239, y=2372
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1227, y=2387
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom in: Current scale factor = 0.5
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom in: Current scale factor = 0.6
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom in: Current scale factor = 0.7
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom in: Current scale factor = 0.8
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1541, y=753
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom out: Current scale factor = 0.7
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom out: Current scale factor = 0.6
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom out: Current scale factor = 0.5
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom out: Current scale factor = 0.4
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom out: Current scale factor = 0.3
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1173, y=2439
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1153, y=2453
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1139, y=2466
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1079, y=2496
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1063, y=2506
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1043, y=2519
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom in: Current scale factor = 0.4
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom in: Current scale factor = 0.5
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom in: Current scale factor = 0.6
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom in: Current scale factor = 0.7
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom in: Current scale factor = 0.8
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=1550, y=797
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom out: Current scale factor = 0.7
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom out: Current scale factor = 0.6
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom out: Current scale factor = 0.5
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom out: Current scale factor = 0.4
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom out: Current scale factor = 0.3
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom in: Current scale factor = 0.4
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Zoom out: Current scale factor = 0.3
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=976, y=2543
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=953, y=2556
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=929, y=2559
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=863, y=2566
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=843, y=2569
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=816, y=2569
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=746, y=2576
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=716, y=2566
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=696, y=2576
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=619, y=2559
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=593, y=2559
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=569, y=2553
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=489, y=2529
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=539, y=2569
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=576, y=2609
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=713, y=2743
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=759, y=2786
# Click on the image to select a point. Use '+' to zoom in, '-' to zoom out, 'n' for next image, 'q' to quit.
# Point selected at: x=796, y=2819
# Data saved to selected_points.csv

# %% [markdown]
# =================================

# %%
import pandas as pd
import cv2
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np

class FanDataset(Dataset):
    def __init__(self, annotations_file, img_size=64):
        self.annotations = pd.read_csv(annotations_file)
        self.img_size = img_size
    
    def __len__(self):
        return len(self.annotations)
    
    def __getitem__(self, idx):
        img_path = self.annotations.iloc[idx, 0]
        image = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        image = cv2.resize(image, (self.img_size, self.img_size)) / 2047.0  # Resize and normalize
        image = image.reshape(1, self.img_size, self.img_size)  # Reshape for CNN input

        # Label: x and y coordinates of the corner
        label = self.annotations.iloc[idx, 1:3].values.astype(np.float32)
        return torch.tensor(image, dtype=torch.float32), torch.tensor(label, dtype=torch.float32)

# 使用自己的标注文件
dataset = FanDataset('selected_points_1126test.csv')
train_loader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
import torch.nn as nn
import torch.nn.functional as F

class CNNPointDetector(nn.Module):
    def __init__(self):
        super(CNNPointDetector, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.fc1 = nn.Linear(64 * 8 * 8, 128)
        self.fc2 = nn.Linear(128, 2)  # Output (x, y) coordinates
        
    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2(x), 2))
        x = F.relu(F.max_pool2d(self.conv3(x), 2))
        x = x.view(-1, 64 * 8 * 8)  # Flatten
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Initialize model
model = CNNPointDetector()

# %%
import torch.optim as optim

# Loss and optimizer
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# Training loop
num_epochs = 550
for epoch in range(num_epochs):
    running_loss = 0.0
    for images, labels in train_loader:
        optimizer.zero_grad()
        
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        # Backward pass and optimization
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
    
    print(f"Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss / len(train_loader):.4f
# Epoch [514/550], Loss: 64642.0445 about 24.666666666666668 min left
# Epoch [515/550], Loss: 64177.2070 about 24.0 min left
# Epoch [516/550], Loss: 63753.9320 about 23.333333333333332 min left
# Epoch [517/550], Loss: 64520.6234 about 22.666666666666668 min left
# Epoch [518/550], Loss: 62501.5133 about 22.0 min left
# Epoch [519/550], Loss: 65367.1516 about 21.333333333333332 min left
# Epoch [520/550], Loss: 63852.7375 about 20.666666666666668 min left
# Epoch [521/550], Loss: 61417.1328 about 20.0 min left
# Epoch [522/550], Loss: 60254.3531 about 19.333333333333332 min left
# Epoch [523/550], Loss: 63289.0391 about 18.666666666666668 min left
# Epoch [524/550], Loss: 62500.8852 about 18.0 min left
# Epoch [525/550], Loss: 60446.9125 about 17.333333333333332 min left
# Epoch [526/550], Loss: 60153.5875 about 16.666666666666668 min left
# Epoch [527/550], Loss: 67552.3711 about 16.0 min left
# Epoch [528/550], Loss: 59804.1070 about 15.333333333333334 min left
# Epoch [529/550], Loss: 60129.2516 about 14.666666666666666 min left
# Epoch [530/550], Loss: 55996.6805 about 14.0 min left
# Epoch [531/550], Loss: 63075.9469 about 13.333333333333334 min left
# Epoch [532/550], Loss: 57767.2289 about 12.666666666666666 min left
# Epoch [533/550], Loss: 55877.1055 about 12.0 min left
# Epoch [534/550], Loss: 57696.8016 about 11.333333333333334 min left
# Epoch [535/550], Loss: 53214.0891 about 10.666666666666666 min left
# Epoch [536/550], Loss: 51988.2883 about 10.0 min left
# Epoch [537/550], Loss: 50017.5648 about 9.333333333333334 min left
# Epoch [538/550], Loss: 47792.3172 about 8.666666666666666 min left
# Epoch [539/550], Loss: 48885.9094 about 8.0 min left
# Epoch [540/550], Loss: 45840.1164 about 7.333333333333333 min left
# Epoch [541/550], Loss: 46442.1180 about 6.666666666666667 min left
# Epoch [542/550], Loss: 46021.2148 about 6.0 min left
# Epoch [543/550], Loss: 44720.9750 about 5.333333333333333 min left
# Epoch [544/550], Loss: 48251.8641 about 4.666666666666667 min left
# Epoch [545/550], Loss: 44044.2430 about 4.0 min left
# Epoch [546/550], Loss: 41977.7086 about 3.3333333333333335 min left
# Epoch [547/550], Loss: 41686.1672 about 2.6666666666666665 min left
# Epoch [548/550], Loss: 42597.3297 about 2.0 min left
# Epoch [549/550], Loss: 44220.0852 about 1.3333333333333333 min left
# Epoch [550/550], Loss: 41708.7500 about 0.6666666666666666 min left

# %%
def evaluate(model, dataset, num_samples=30):
    model.eval()
    with torch.no_grad():
        for i in range(num_samples):
            img, label = dataset[i]
            img = img.unsqueeze(0)  # Add batch dimension
            
            # Model prediction
            prediction = model(img)
            print(f"True: {label.numpy()}, Predicted: {prediction.numpy().flatten()}")

# Test on some sample
evaluate(model, dataset)
# Out:
# True: [2374. 2429.], Predicted: [2347.8853 2483.734 ]
# True: [2869. 2437.], Predicted: [2901.2551 2456.575 ]
# True: [2907. 2384.], Predicted: [2895.3508 2492.4067]
# True: [2924. 2309.], Predicted: [2816.6062 2343.421 ]
# True: [2662. 1697.], Predicted: [2616.9502 1664.3225]
# True: [2543. 1531.], Predicted: [2621.806  1521.9154]
# True: [2411. 1355.], Predicted: [2428.1208 1337.626 ]
# True: [2469. 1651.], Predicted: [2424.9668 1711.144 ]
# True: [2491. 1765.], Predicted: [2388.5059 1757.7783]
# True: [2492. 1862.], Predicted: [2412.645  1784.1642]
# True: [2219. 2124.], Predicted: [2155.366  2132.2395]
# True: [2112. 2129.], Predicted: [2128.967  2082.1562]
# True: [2422. 2634.], Predicted: [2431.132  2592.3887]
# True: [1992. 2117.], Predicted: [1971.51  2097.458]
# True: [1164. 1824.], Predicted: [1221.2678 1787.3195]
# True: [1252. 1934.], Predicted: [1197.6165 1944.7664]
# True: [1394. 2077.], Predicted: [1368.2308 2023.23  ]
# True: [2496. 2736.], Predicted: [2528.5356 2761.9802]
# True: [1943. 2556.], Predicted: [1935.1494 2602.6614]
# True: [2013. 2599.], Predicted: [1969.4457 2606.345 ]
# True: [2066. 2619.], Predicted: [1985.2372 2473.1748]
# True: [2093. 2419.], Predicted: [2053.0874 2400.3782]
# True: [2553. 2813.], Predicted: [2578.1074 2829.7083]
# True: [2049. 2319.], Predicted: [2002.9677 2445.6196]
# True: [1987. 2204.], Predicted: [1988.3676 2248.0466]
# True: [2553. 2879.], Predicted: [2486.2104 2933.7273]
# True: [2493. 2829.], Predicted: [2437.3792 2851.3694]
# True: [2416. 2753.], Predicted: [2360.4763 2787.7812]
# True: [2043. 2296.], Predicted: [2100.0115 2303.0388]
# True: [2213. 2369.], Predicted: [2196.3672 2345.6482]

# %%
torch.save(model.state_dict(), './fan_corner_detector_1125.pth')

# %% [markdown]
# ===================================================1114

# %%
import torch
model = CNNPointDetector()
model.load_state_dict(torch.load('fan_corner_detector_1126.pth'))
model.eval()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 import torch
# ----> 2 model = CNNPointDetector()
#       3 model.load_state_dict(torch.load('fan_corner_detector_1126.pth'))
#       4 model.eval()
#
# NameError: name 'CNNPointDetector' is not defined

# %%
import pandas as pd
import cv2
import torch
from torch.utils.data import Dataset, DataLoader
import numpy as np

# %%
class FanDataset(Dataset):
    def __init__(self, annotations_file, img_size=64):
        self.annotations = pd.read_csv(annotations_file)
        self.img_size = img_size
    
    def __len__(self):
        return len(self.annotations)
    
    def __getitem__(self, idx):
        img_path = self.annotations.iloc[idx, 0]
        image = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        image = cv2.resize(image, (self.img_size, self.img_size)) / 2047.0  # Resize and normalize
        image = image.reshape(1, self.img_size, self.img_size)  # Reshape for CNN input

        # Label: x and y coordinates of the corner
        label = self.annotations.iloc[idx, 1:3].values.astype(np.float32)
        return torch.tensor(image, dtype=torch.float32), torch.tensor(label, dtype=torch.float32)

# 使用自己的标注文件
dataset = FanDataset('selected_points_2.csv')

# %%
def evaluate(model, dataset, num_samples=40):
    model.eval()
    with torch.no_grad():
        for i in range(num_samples):
            img, label = dataset[i]
            img = img.unsqueeze(0)  # Add batch dimension
            
            # Model prediction
            prediction = model(img)
            print(f"True: {label.numpy()}, Predicted: {prediction.numpy().flatten()}")

# Test on some sample
evaluate(model, dataset)
# Out:
# True: [1078. 1428.], Predicted: [1068.0464 1406.3397]
# True: [1094. 1444.], Predicted: [1084.3955 1422.9469]
# True: [1119. 1459.], Predicted: [1101.6335 1460.2899]
# True: [1136. 1474.], Predicted: [1131.2876 1477.3566]
# True: [1153. 1486.], Predicted: [1150.9265 1484.466 ]
# True: [1169. 1501.], Predicted: [1159.7096 1487.786 ]
# True: [1188. 1513.], Predicted: [1164.613 1512.206]
# True: [1203. 1524.], Predicted: [1185.8314 1508.0747]
# True: [1219. 1538.], Predicted: [1197.6195 1522.8973]
# True: [1239. 1551.], Predicted: [1203.9678 1532.4856]
# True: [1253. 1561.], Predicted: [1220.4241 1540.379 ]
# True: [1266. 1571.], Predicted: [1253.1174 1555.8607]
# True: [1281. 1583.], Predicted: [1251.1953 1553.0763]
# True: [1296. 1591.], Predicted: [1284.8665 1588.1522]
# True: [1311. 1601.], Predicted: [1304.0955 1608.6276]
# True: [1318. 1608.], Predicted: [1322.063  1620.7413]
# True: [1336. 1616.], Predicted: [1340.7534 1620.39  ]
# True: [1348. 1626.], Predicted: [1347.2761 1613.0803]
# True: [1358. 1633.], Predicted: [1361.6704 1634.7317]
# True: [1371. 1639.], Predicted: [1358.6711 1635.2828]
# True: [1383. 1646.], Predicted: [1379.4233 1642.9401]
# True: [1394. 1651.], Predicted: [1400.4185 1658.0519]
# True: [1401. 1656.], Predicted: [1408.1593 1648.8827]
# True: [1414. 1661.], Predicted: [1403.4469 1653.9839]
# True: [1427. 1665.], Predicted: [1395.9512 1660.0686]
# True: [1437. 1669.], Predicted: [1411.716  1667.5803]
# True: [1443. 1673.], Predicted: [1421.8926 1671.3217]
# True: [1447. 1675.], Predicted: [1440.6958 1684.0355]
# True: [1461. 1679.], Predicted: [1444.0364 1693.4811]
# True: [1465. 1681.], Predicted: [1455.654  1686.0773]
# True: [1475. 1681.], Predicted: [1451.8574 1693.2144]
# True: [1483. 1685.], Predicted: [1478.1227 1699.7247]
# True: [1485. 1685.], Predicted: [1505.8789 1710.4596]
# True: [1489. 1685.], Predicted: [1511.3218 1694.8057]
# True: [1495. 1681.], Predicted: [1491.03   1687.7572]
# True: [1503. 1681.], Predicted: [1497.7672 1696.1268]
# True: [1507. 1679.], Predicted: [1494.2708 1686.9559]
# True: [1517. 1681.], Predicted: [1497.7285 1656.1122]
# True: [1515. 1673.], Predicted: [1519.2692 1669.6737]
# True: [1519. 1669.], Predicted: [1517.7883 1654.9683]

# %% [markdown]
# ## load

# %%
import torch
import torch.optim as optim

import torch.nn as nn
import torch.nn.functional as F



class CNNPointDetector(nn.Module):
    def __init__(self):
        super(CNNPointDetector, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, stride=1, padding=1)
        self.conv3 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.fc1 = nn.Linear(64 * 8 * 8, 128)
        self.fc2 = nn.Linear(128, 2)  # Output (x, y) coordinates
        
    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2(x), 2))
        x = F.relu(F.max_pool2d(self.conv3(x), 2))
        x = x.view(-1, 64 * 8 * 8)  # Flatten
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# Initialize model
model = CNNPointDetector()
# 初始化模型
model = CNNPointDetector()
model.load_state_dict(torch.load('fan_corner_detector_1126.pth'))  # 加载模型参数
model.train()
# Out:
# C:\Users\raykuo7\AppData\Local\Temp\ipykernel_19620\2707019372.py:31: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('fan_corner_detector_1126.pth'))  # 加载模型参数
# CNNPointDetector(
#   (conv1): Conv2d(1, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv2): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (fc1): Linear(in_features=4096, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=2, bias=True)
# )
